# %%
from kafka import KafkaProducer
import json
import random
import time

producer = KafkaProducer(
    bootstrap_servers="kafka:9092",
    value_serializer=lambda v: json.dumps(v).encode("utf-8")
)

user_ids = [101, 102, 103, 104, 105]

print("Starting Transaction Producer...")

for i in range(5):

    tx_data = {
        "tx_id": i,
        "userId": random.choice(user_ids),
        "amount": round(random.uniform(100, 15000), 2),
        "timestamp": time.time()
    }

    producer.send(
        "fraud-detection",
        value=tx_data
    )

    print(f"Sent: {tx_data}")

    time.sleep(0.1)

producer.flush()
# Out:
# Starting Transaction Producer...
# Sent: {'tx_id': 0, 'userId': 105, 'amount': 7124.33, 'timestamp': 1781927267.2042298}
# Sent: {'tx_id': 1, 'userId': 102, 'amount': 3038.78, 'timestamp': 1781927269.3044786}
# Sent: {'tx_id': 2, 'userId': 104, 'amount': 6336.98, 'timestamp': 1781927271.3052607}
# Sent: {'tx_id': 3, 'userId': 102, 'amount': 11622.7, 'timestamp': 1781927273.3057353}
# Sent: {'tx_id': 4, 'userId': 105, 'amount': 4216.98, 'timestamp': 1781927275.3071394}
